# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data.csv")
data.head()
# Out:
#                             Customer ID  Age  Gender  Annual Income  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
#
#    Spending Score
# 0              89
# 1              95
# 2              76
# 3              57
# 4              76

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15079 entries, 0 to 15078
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer ID     15079 non-null  object
#  1   Age             15079 non-null  int64
#  2   Gender          15079 non-null  object
#  3   Annual Income   15079 non-null  int64
#  4   Spending Score  15079 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 589.1+ KB

# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (3.3.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade numpy pandas scipy
# Out:
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.5.3)
# Collecting pandas
#   Using cached pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# Successfully installed pandas-2.2.2
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires scipy<1.12,>=1.4.1, but you have scipy 1.13.1 which is incompatible.
# sktime 0.26.1 requires pandas<2.2.0,>=1.1, but you have pandas 2.2.2 which is incompatible.
# sktime 0.26.1 requires scikit-learn<1.5.0,>=0.24, but you have scikit-learn 1.5.0 which is incompatible.
# pycaret 3.3.0 requires pandas<2.2.0, but you have pandas 2.2.2 which is incompatible.
# pycaret 3.3.0 requires scipy<=1.11.4,>=1.6.1, but you have scipy 1.13.1 which is incompatible.

# %%
data.describe()
# Out:
#                 Age  Annual Income  Spending Score
# count  15079.000000   15079.000000    15079.000000
# mean      54.191591  109742.880562       50.591617
# std       21.119207   52249.425866       28.726977
# min       18.000000   20022.000000        1.000000
# 25%       36.000000   64141.000000       26.000000
# 50%       54.000000  109190.000000       51.000000
# 75%       72.000000  155008.000000       75.000000
# max       90.000000  199974.000000      100.000000

# %%
data.shape
# Out:
# (15079, 5)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                                 Customer ID  Age  Gender  Annual Income  \
# 0      d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1      1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2      e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3      9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4      64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
# ...                                     ...  ...     ...            ...
# 15074  a0504768-a85f-4930-ac24-55bc8e4fec9e   29  Female          97723
# 15075  a08c4e0e-d1fe-48e7-9366-aab11ae409cd   22    Male          73361
# 15076  0e87c25a-268c-401a-8ba1-7111dcde6f1a   18  Female         112337
# 15077  5f388cbe-3373-4e16-b743-38f508f2249f   26  Female          94312
# 15078  b8b8f561-ebca-4401-8afe-544c906554ba   19    Male          78045
#
#        Spending Score
# 0                  89
# 1                  95
# 2                  76
# 3                  57
# 4                  76
# ...               ...
# 15074              30
# 15075              74
# 15076              48
# 15077               5
# 15078               2
#
# [15079 rows x 5 columns]>

# %%
data.isnull().sum()
# Out:
# Customer ID       0
# Age               0
# Gender            0
# Annual Income     0
# Spending Score    0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Customer ID       False
# Age               False
# Gender            False
# Annual Income     False
# Spending Score    False
# dtype: bool

# %%
sns.scatterplot(data=data,x='Annual Income',y='Spending Score',hue='Age',style='Gender', cmap='viridis')
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\seaborn\relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)
# <Axes: xlabel='Annual Income', ylabel='Spending Score'>

# %%
targets = ['Age','Annual Income','Spending Score']
data1=data[targets].copy()
data1.head()
# Out:
#    Age  Annual Income  Spending Score
# 0   30         151479              89
# 1   58         185088              95
# 2   62          70912              76
# 3   23          55460              57
# 4   24         153752              76

# %%
data.head()
# Out:
#                             Customer ID  Age  Gender  Annual Income  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
#
#    Spending Score
# 0              89
# 1              95
# 2              76
# 3              57
# 4              76

# %%
data1.max()
# Out:
# Age                   90
# Annual Income     199974
# Spending Score       100
# dtype: int64

# %%
data1.min()
# Out:
# Age                  18
# Annual Income     20022
# Spending Score        1
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(1,10))

# %%
scaler.fit(data1)
# Out:
# MinMaxScaler(feature_range=(1, 10))

# %%
data1=scaler.transform(data1)

# %%
data1=pd.DataFrame(data=data1, columns=targets)

# %%
data1.describe()
# Out:
#                 Age  Annual Income  Spending Score
# count  15079.000000   15079.000000    15079.000000
# mean       5.523949       5.487241        5.508329
# std        2.639901       2.613168        2.611543
# min        1.000000       1.000000        1.000000
# 25%        3.250000       3.206538        3.272727
# 50%        5.500000       5.459589        5.545455
# 75%        7.750000       7.751100        7.727273
# max       10.000000      10.000000       10.000000

# %%
data1.head()
# Out:
#      Age  Annual Income  Spending Score
# 0  2.500       7.574603        9.000000
# 1  6.000       9.255501        9.545455
# 2  6.500       3.545179        7.818182
# 3  1.625       2.772373        6.090909
# 4  1.750       7.688284        7.818182

# %%
def random_centroids(data1, k):
    centroids = []
    for i in range(k):
        centroid = data1.apply(lambda x: float(x.sample()))
        centroids.append(centroid)
    return pd.concat(centroids, axis=1)

# %%
centroids = random_centroids(data1,3)
print(centroids)
# Out:
#                        0         1         2
# Age             9.750000  8.000000  2.500000
# Annual Income   9.000183  1.035359  3.677164
# Spending Score  6.272727  2.909091  6.818182

# %%
def get_labels(data1, centroids):
    distances = centroids.apply(lambda x: np.sqrt(((data1 - x) ** 2).sum(axis=1)))
    return distances.idxmin(axis=1)

# %%
labels = get_labels(data1, centroids)

# %%
labels.value_counts()
# Out:
# 2    7384
# 0    4528
# 1    3167
# dtype: int64

# %%
def new_centroids(data1, labels, k):
    centroids = data1.groupby(labels).apply(lambda x: np.exp(np.log(x).mean())).T
    return centroids

# %%
from sklearn.decomposition import PCA
from IPython.display import clear_output

# %%
def plot_clusters(data, labels, centroids, iteration):
    pca = PCA(n_components=2)
    data1_2d = pca.fit_transform(data1)
    centroids_2d = pca.transform(centroids.T)
    clear_output(wait=True)
    plt.title(f'Iteration {iteration}')
    plt.scatter(x=data1_2d[:,0], y=data1_2d[:,1], c=labels)
    plt.scatter(x=centroids_2d[:,0], y=centroids_2d[:,1])
    plt.show()

# %%
max_iterations = 100
centroid_count = 5

centroids = random_centroids(data1, centroid_count)
old_centroids = pd.DataFrame()
iteration = 1

while iteration < max_iterations and not centroids.equals(old_centroids):
    old_centroids = centroids
    
    labels = get_labels(data1, centroids)
    centroids = new_centroids(data1, labels, centroid_count)
    plot_clusters(data1, labels, centroids, iteration)
    iteration += 1

# %%
cluster22=data[labels == 0][['Customer ID','Gender']+ targets]
cluster22
# Out:
#                                 Customer ID  Gender  Age  Annual Income  \
# 8      86f73b1a-6a91-4d7e-ad21-0aefcf6111cc    Male   83          47743
# 9      b20fe0a0-e254-4116-b804-5403bb2f59ea  Female   62          63448
# 17     51d7be3e-84c9-464a-85e8-0a95b568d90e    Male   89          38708
# 18     8bbbdbbe-7f8a-4c9c-afed-f6969f49e9ac    Male   65          87270
# 26     c2fd4929-fc3e-423a-8dd9-1fb239ef4de6    Male   79         109550
# ...                                     ...     ...  ...            ...
# 15052  8945985e-60de-4a8f-9b7b-b3c538581fd8  Female   88          24429
# 15061  690747f5-9039-43b6-b959-3575661f532a    Male   81          70574
# 15066  7051c7e2-5864-470c-9cea-15e5d6f9efcf  Female   69          32370
# 15068  2b5361cb-9fe3-4129-aab5-fb6c45e22051  Female   71          65773
# 15073  21c26582-4425-4296-8305-4045edba61b8  Female   70         108936
#
#        Spending Score
# 8                  34
# 9                   3
# 17                 97
# 18                  3
# 26                  7
# ...               ...
# 15052              74
# 15061              35
# 15066              39
# 15068              60
# 15073               6
#
# [2733 rows x 5 columns]

# %%
cluster22.describe()
# Out:
#                Age  Annual Income  Spending Score
# count  2733.000000    2733.000000     2733.000000
# mean     73.592389   61434.821808       36.765459
# std      10.567775   25736.986808       23.414955
# min      50.000000   20089.000000        1.000000
# 25%      65.000000   39342.000000       18.000000
# 50%      75.000000   59717.000000       34.000000
# 75%      83.000000   81578.000000       53.000000
# max      90.000000  125458.000000      100.000000

# %%
sns.heatmap(cluster22.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
cluster2=data[labels == 1][['Customer ID','Gender']+targets]
cluster2
# Out:
#                                 Customer ID  Gender  Age  Annual Income  \
# 7      43417ade-6b17-431e-ae76-d8ed26aa46ac    Male   24          70476
# 12     eb0e4ebc-fcc1-424f-b083-81987583ecc6    Male   25          87576
# 19     baa61fc0-4a1f-4210-916b-669d1ec44dbd    Male   26          45518
# 23     9c702610-d6ce-48fe-9857-9e295e161ceb  Female   39          48212
# 43     3e260c72-5788-4641-8dad-9cc7a4eaafef    Male   45          82425
# ...                                     ...     ...  ...            ...
# 15064  1a695b18-c729-471f-9243-f2ae9dbae9db  Female   35          54239
# 15067  33f77ca2-9eee-4e60-b5dc-9b95365b10f3    Male   32          59424
# 15074  a0504768-a85f-4930-ac24-55bc8e4fec9e  Female   29          97723
# 15077  5f388cbe-3373-4e16-b743-38f508f2249f  Female   26          94312
# 15078  b8b8f561-ebca-4401-8afe-544c906554ba    Male   19          78045
#
#        Spending Score
# 7                  17
# 12                 17
# 19                 12
# 23                 36
# 43                 39
# ...               ...
# 15064               7
# 15067              26
# 15074              30
# 15077               5
# 15078               2
#
# [1769 rows x 5 columns]

# %%
cluster2.describe()
# Out:
#                Age  Annual Income  Spending Score
# count  1769.000000    1769.000000     1769.000000
# mean     35.371962   60785.235161       24.831543
# std      10.190861   24692.284163       14.606835
# min      18.000000   20177.000000        1.000000
# 25%      27.000000   40001.000000       12.000000
# 50%      35.000000   58698.000000       25.000000
# 75%      44.000000   81767.000000       37.000000
# max      55.000000  111839.000000       56.000000

# %%
cluster33=data[labels == 2][['Customer ID','Gender']+targets]
cluster33
# Out:
#                                 Customer ID  Gender  Age  Annual Income  \
# 5      7e211337-e92f-4140-8231-5c9ac7a2aa12    Male   42         158335
# 6      30661d57-eeb5-4886-970a-9c7d0f260ad8  Female   27         163501
# 10     49ba3e9d-a590-4303-b443-e794d0364c11    Male   37         170566
# 16     b43f995c-c9ab-4c58-8f71-949de233ac71    Male   19         198682
# 20     05948202-e483-482a-9c02-6a655498002b    Male   21         199879
# ...                                     ...     ...  ...            ...
# 15046  5f2e86a3-d244-488b-ad36-c79cf46be46b  Female   35         192517
# 15047  7a509b25-8e2f-4907-a2d9-7e90723528c6  Female   50         190722
# 15059  f4fdd6f7-f6cb-4c23-9964-6c715c754d8b  Female   26         179159
# 15062  1a53a4a4-c16b-4386-bf28-5842cd3f3f9b  Female   24         166849
# 15076  0e87c25a-268c-401a-8ba1-7111dcde6f1a  Female   18         112337
#
#        Spending Score
# 5                  40
# 6                  37
# 10                 75
# 16                 82
# 20                 49
# ...               ...
# 15046              34
# 15047               7
# 15059              55
# 15062              74
# 15076              48
#
# [2532 rows x 5 columns]

# %%
cluster33.describe()
# Out:
#                Age  Annual Income  Spending Score
# count  2532.000000    2532.000000     2532.000000
# mean     34.384676  158027.509479       34.112954
# std      10.698359   26837.210596       22.189512
# min      18.000000  100605.000000        1.000000
# 25%      25.000000  136106.000000       15.000000
# 50%      33.000000  160848.000000       32.000000
# 75%      43.000000  180918.500000       50.000000
# max      61.000000  199974.000000       95.000000

# %%
cluster4=data[labels == 3][['Customer ID','Gender']+targets]
cluster4
# Out:
#                                 Customer ID  Gender  Age  Annual Income  \
# 0      d410ea53-6661-42a9-ad3a-f554b05fd2a7    Male   30         151479
# 2      e81aa8eb-1767-4b77-87ce-1620dc732c5e  Female   62          70912
# 3      9795712a-ad19-47bf-8886-4f997d6046e3    Male   23          55460
# 4      64139426-2226-4cd6-bf09-91bce4b4db5e    Male   24         153752
# 11     4be5f5b0-83f6-4bd2-9056-18a8d5414066  Female   63          89355
# ...                                     ...     ...  ...            ...
# 15069  5ba45b3d-8dfa-4b93-8f81-5e0a40aff47e    Male   55          71393
# 15070  50fbfed1-7d60-4398-bf45-3f246bb6369f  Female   45          68342
# 15071  720d5085-0248-4939-b8c1-9261b5896cb5  Female   40          27768
# 15072  02da8108-fe4f-4300-a4d3-e2210f8d240f  Female   35         105107
# 15075  a08c4e0e-d1fe-48e7-9366-aab11ae409cd    Male   22          73361
#
#        Spending Score
# 0                  89
# 2                  76
# 3                  57
# 4                  76
# 11                 80
# ...               ...
# 15069              85
# 15070              79
# 15071              88
# 15072              49
# 15075              74
#
# [3620 rows x 5 columns]

# %%
cluster4.describe()
# Out:
#                Age  Annual Income  Spending Score
# count  3620.000000    3620.000000     3620.000000
# mean     42.048343   84950.459945       79.572652
# std      15.291029   40701.851552       14.256559
# min      18.000000   20022.000000       45.000000
# 25%      30.000000   51998.250000       69.000000
# 50%      41.000000   81592.000000       81.000000
# 75%      53.000000  112083.500000       92.000000
# max      86.000000  199963.000000      100.000000

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(5)
kmeans.fit(data1)
# Out:
# KMeans(n_clusters=5)

# %%
a=kmeans.get_feature_names_out()

# %%
a[0]
# Out:
# 'kmeans0'

# %%
pd.DataFrame(kmeans.cluster_centers_, columns=targets).T
# Out:
#                        0         1         2         3         4
# Age             7.924182  5.726773  7.566529  3.063853  3.344184
# Annual Income   5.306870  7.968237  3.362720  3.159381  7.689202
# Spending Score  3.055416  7.796747  7.723342  5.561069  3.380499

# %%
new=np.array([[84,50000,50]])

# %%
scaled_data = scaler.transform(new)
scaled_data
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([[9.25      , 2.49929981, 5.45454545]])

# %%
kmeans.predict(scaled_data)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([2])

# %%
data.head()
# Out:
#                             Customer ID  Age  Gender  Annual Income  \
# 0  d410ea53-6661-42a9-ad3a-f554b05fd2a7   30    Male         151479
# 1  1770b26f-493f-46b6-837f-4237fb5a314e   58  Female         185088
# 2  e81aa8eb-1767-4b77-87ce-1620dc732c5e   62  Female          70912
# 3  9795712a-ad19-47bf-8886-4f997d6046e3   23    Male          55460
# 4  64139426-2226-4cd6-bf09-91bce4b4db5e   24    Male         153752
#
#    Spending Score
# 0              89
# 1              95
# 2              76
# 3              57
# 4              76

# %%
X=data.drop(columns=['Customer ID','Gender'])

# %%
X.shape
# Out:
# (15079, 3)

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
column_trans = make_column_transformer(
    (scaler, ['Age', 'Annual Income', 'Spending Score']),
    remainder='passthrough')

# %%
column_trans.fit_transform(X);

# %%
k_range = range(1,10)
sse = []
for i in k_range:
    Kmeans = KMeans(n_clusters=i, random_state=0)
    pipe = make_pipeline(column_trans, Kmeans)
   
    pipe.fit(X)
    
    sse.append(pipe.named_steps['kmeans'].inertia_)

# %%
sse
# Out:
# [310876.4492487762,
#  232070.37899240397,
#  184822.86718019267,
#  148009.63364735933,
#  124036.4849295413,
#  102323.68512724419,
#  89586.26029390356,
#  77759.90258105856,
#  72923.1975345492]

# %%
plt.plot(k_range, sse)
plt.plot(range(1,10),sse, linewidth=4, markersize=12,marker='o')
plt.xlabel('Number of K')
plt.ylabel('SSE')
plt.show()

# %%
Kmeans = KMeans(n_clusters=5, init = "k-means++", random_state = 0)

# %%
pipeline = make_pipeline(column_trans, Kmeans)
pipeline
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('minmaxscaler',
#                                                   MinMaxScaler(feature_range=(1,
#                                                                               10)),
#                                                   ['Age', 'Annual Income',
#                                                    'Spending Score'])])),
#                 ('kmeans', KMeans(n_clusters=5, random_state=0))])

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline([
    ('preprocessing', column_trans),
    ('kmeans', KMeans(n_clusters=5, init='k-means++', random_state=0))
])

# %%
clusters = pipeline.fit_predict(X)

# %%
X["Cluster"] = clusters

# %%
X.head()
# Out:
#    Age  Annual Income  Spending Score  Cluster
# 0   30         151479              89        3
# 1   58         185088              95        3
# 2   62          70912              76        4
# 3   23          55460              57        3
# 4   24         153752              76        3

# %%
import pickle
pickle.dump(pipe,open("goldenproject.pkl","wb"))
model=pickle.load(open('goldenproject.pkl','rb'))
